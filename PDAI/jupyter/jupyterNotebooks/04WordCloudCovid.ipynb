# %% [markdown]
# <center><font size="+4">Programming & Data Analytics & AI 1 2025/2026</font></center>
# <center><font size="+2">Sant'Anna School of Advanced Studies, Pisa, Italy</font></center>
# <center><img src="https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20242025/raw/main/PDAI/jupyter/jupyterNotebooks/images/sssaLEMBEDSdtu.png" width="900" alt="L'EMbeDS"></center>
#
# <center><font size="+2">Course responsible</font></center>
# <center><font size="+2">Andrea Vandin a.vandin@santannapisa.it</font></center>
#
# ---

# %% [markdown]
# <center><font size="+4">Lecture 4: </font></center>
# <center><font size="+2"> Creation of word clouds for COVID-related online news</font></center>
# </center>

# %% [markdown]
# ---

# %%
from IPython.display import Image, display
url_github_repo="https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20252026/raw/main/PDAI/"

# %% [markdown]
# # Computing and visulatizing the most important words in online news

# %% [markdown]
# This example shows that functions can hide a lot of complexity.
# * E.g., we can download remote data by just invoking a function
# * In particular, in this example we will:
#     1. Download all the articles from the online service [NewsAPI](https://newsapi.org/)
#          - An online service is like a function running on the internet...
#     2. Combine the articles into one document (`str`)
#     3. Clean data
#     4. Compute word-frequency pairs
#         - Word 'ciao' appears 3 times, word 'hello' appears 6 times ...
#     5. Visualize the analysis in a Word Cloud

# %% [markdown]
# *Some definitions:*

# %% [raw]
# ![](images/web_server_web_service.png)

# %%
#from IPython.display import Image, display
#url_github_repo="https://github.com/EMbeDS-education/StatsAndComputing20232024/raw/main/PDAI/"
img=Image(url_github_repo+'jupyter/jupyterNotebooks/images/web_server_web_service.png',width=800)
display(img)

# %% [markdown]
# A **web service** is an application run by a web server (a remote computer connected to the interent).
# - The service can be called/invoked from some other computers connected to the internet
# - The service will _return_ data in a format that can't be sent over the internet
#   - A little bit like a webpage, which is loaded from some remote server, and visualized in a browser
#   - However, here data is not visualized but sent in a format that can be processed by programs.
#   - Examples of used formats are XML (especially SOAP or so) or JSON.
#
# An **Application Programming Interface (API)** allows two programs to communicate with one another.
# - An API defines the functions for one software program to interact with the other.

# %% [markdown]
# This document has been __created by Daniele Licari__ and elaborated by Andrea Vandin.

# %% [markdown]
# # The modules we need to use

# %%
# %pip install newsapi-python
# %pip install wordcloud
# Out:
# Collecting newsapi-python
#   Downloading newsapi_python-0.2.7-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting requests<3.0.0 (from newsapi-python)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0->newsapi-python)
#   Using cached charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0->newsapi-python)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.14/site-packages (from requests<3.0.0->newsapi-python) (2.5.0)
# Collecting certifi>=2017.4.17 (from requests<3.0.0->newsapi-python)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Downloading newsapi_python-0.2.7-py2.py3-none-any.whl (7.9 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl (207 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Installing collected packages: idna, charset_normalizer, certifi, requests, newsapi-python
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [newsapi-python]
# Successfully installed certifi-2025.11.12 charset_normalizer-3.4.4 idna-3.11 newsapi-python-0.2.7 requests-2.32.5
# Note: you may need to restart the kernel to use updated packages.
# Collecting wordcloud
#   Downloading wordcloud-1.9.4.tar.gz (27.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.6/27.6 MB 75.3 kB/s  0:06:52m0:00:0100:13
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.6.1 in ./.venv/lib/python3.14/site-packages (from wordcloud) (2.3.5)
# Requirement already satisfied: pillow in ./.venv/lib/python3.14/site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.14/site-packages (from wordcloud) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.14/site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.14/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.14/site-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.14/site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.14/site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.14/site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.14/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (pyproject.toml) ... done
#   Created wheel for wordcloud: filename=wordcloud-1.9.4-cp314-cp314-macosx_10_15_universal2.whl size=238817 sha256=a64a4db93a1572d71fea28597ed72c7dc9a10f0d6cce56878e7c1cea0e068691
#   Stored in directory: /Users/andreavandin/Library/Caches/pip/wheels/38/3b/19/154b2215b636aee485efaa8be305a2d22b0a1707516894200c
# Successfully built wordcloud
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
#We might also get some errors like 'Only supported for TrueType fonts'
#We can fix them running these installations

# %pip install --upgrade pip 
# %pip install --upgrade Pillow
# Out:
# Requirement already satisfied: pip in ./.venv/lib/python3.14/site-packages (25.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: Pillow in ./.venv/lib/python3.14/site-packages (12.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# integrating News API into your Python application 
from newsapi import NewsApiClient 

# creating wordclouds into your Python application 
from wordcloud import WordCloud, STOPWORDS

#  In Python, string.punctuation will give the sets of all punctuations. 
import string

import matplotlib.pyplot as plt

# %%
STOPWORDS
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %% [markdown]
# __NewsApiClient__ is a local client for the online service [__NewsAPI__](https://newsapi.org/) that allows you to get news from [eveywhere in the world](https://newsapi.org/sources)
# * Intuitively, an online service is like an online function running in a remote server (computer)
# * A local client is a piece of code runnning in your machine that communicates with the online service
#   * It allows you to easily interact with the online service
#   * The interaction is typically done through a set of message exchanges as prescribed by the APIs of the service
# * We need a `api_key` that is a univoque identifier
#   * necessary when making requests to be identified
#   * __can be obtained registering [here](https://newsapi.org/register)__

# %% [markdown]
# There exist many online services accessible with Python (e.g. [Twitter API](https://www.tweepy.org/))
# * Most of them follow this api-key approach
# * E.g. to enforce subscriptions
# <!-- * In our case, __we are using a free subscription that allows us to only get the first 250 characters from a news item__ -->

# %% [markdown]
# # Data loading

# %% [markdown]
# We first get the most relevant articles (top 100) about coronavirus, published in usa-today
# * This looks like a [normal function invocation](https://newsapi.org/docs/client-libraries/python)
# * But under the hood a lot happens to contact the remote service
# (https://newsapi.org/v2/everything?q=coronavirus&sources=usa-today&language=en&pageSize=100&sortBy=relevancy&apiKey=1f6979fc955b465f9b076310217a19a3)
#
# Luckily, the function `get_everything` hides this complexity to us

# %%
#
#Guide from:
# https://newsapi.org/docs/client-libraries/python
#

# from newsapi import NewsApiClient

# # Init
# newsapi = NewsApiClient(api_key='1f6979fc955b465f9b076310217a19a3')

# # /v2/top-headlines
# top_headlines = newsapi.get_top_headlines(q='bitcoin',
#                                           sources='bbc-news,the-verge',
#                                           category='business',
#                                           language='en',
#                                           country='us')

# # /v2/everything
# all_articles = newsapi.get_everything(q='bitcoin',
#                                       sources='bbc-news,the-verge',
#                                       domains='bbc.co.uk,techcrunch.com',
#                                       #from_param='2017-12-01',
#                                       #to='2017-12-12',
#                                       language='en',
#                                       sort_by='relevancy',
#                                       page=2)

# # /v2/top-headlines/sources
# #sources = newsapi.get_sources()

# %%
my_api_key='1f6979fc955b465f9b076310217a19a3'
#newsapi = NewsApiClient(api_key='345f8a0aa8c64d549fde1d8343d036f8')
newsapi = NewsApiClient(api_key=my_api_key)
json_data = newsapi.get_everything(
                                    #q='coronavirus',        # All the articles that contain this word
                                    q='covid',
                                    #q='hamas',              # All the articles that contain this word
                                    language='en',
                                    #sources = 'usa-today', # The newspaper of interest
                                    sources = 'cnn', # The newspaper of interest
                                    #sources = 'bbc-news', # The newspaper of interest
                                    #sources = 'bbc-news,the-verge'
                                    #
                                    page_size=100,           # Get 100 articles
                                    sort_by='relevancy'
                                    )
#There exist many more parameters allowing us the ask for more articles, different sources, etc

#print(json_data)

# %%
json_data
# Out:
# {'status': 'ok',
#  'totalResults': 18,
#  'articles': [{'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Deidre McPhillips, CNN',
#    'title': 'Canada is poised to lose its measles elimination status — and the US could, too',
#    'description': 'Monday marks a full year of continuous measles transmission in Canada, a milestone that’s poised to set the country back decades on a global health...',
#    'url': 'https://www.cnn.com/2025/10/27/health/measles-elimination-canada-us-who',
#    'urlToImage': 'https://media.zenfs.com/en/cnn_articles_875/a33f02fd4b2d2da1f28596d69fa6b7d1',
#    'publishedAt': '2025-10-27T11:00:01Z',
#    'content': 'Monday marks a full year of continuous measles transmission in Canada, a milestone thats poised to set the country back decades on a global health commitment. Ongoing transmission in the United State… [+8753 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Issy Ronald, CNN',
#    'title': 'Qantas releases first images of jet that will fly nonstop from Sydney to London and New York',
#    'description': 'Australia’s flag carrier will use Airbus A350-1000ULR jets for its “Project Sunrise” service which will fly nonstop from Sydney to London and New York.',
#    'url': 'https://www.cnn.com/2025/11/07/travel/qantas-airbus-project-sunrise-plane-nonstop-intl-scli',
#    'urlToImage': 'https://media.zenfs.com/en/cnn_articles_875/0ae7372671db0681955525fd3410e0b6',
#    'publishedAt': '2025-11-07T14:50:24Z',
#    'content': 'Just 80 years ago, traveling to Sydney or Melbourne from London or New York took more than a week.\r\nNow, a passenger aircraft that can complete make the journey without stopping is in the final stage… [+2434 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Deidre McPhillips',
#    'title': 'Autism diagnosis rates higher among children born to mothers who had Covid-19 during pregnancy, study suggests | CNN',
#    'description': 'Children may be more likely to be diagnosed with autism and other neurodevelopment disorders if their mother had a Covid-19 infection while pregnant, according to a new study.',
#    'url': 'https://www.cnn.com/2025/10/30/health/autism-covid-pregnancy',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-1322499124.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-10-31T00:29:08Z',
#    'content': 'Children may be more likely to be diagnosed with autism and other neurodevelopment disorders if their mother had a Covid-19 infection while pregnant, according to a new study.\r\nResearchers from Massa… [+3906 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Bryan Mena, Elisabeth Buchwald, John Towfighi, Matt Egan',
#    'title': 'Live updates: Fed looks set to cut rates for second time this year despite data blackout due to government shutdown',
#    'description': 'The Federal Reserve was widely expected to lower interest rates by a quarter point in order to support the waning job market.',
#    'url': 'https://www.cnn.com/business/live-news/federal-reserve-interest-rate-10-29-25',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/2025-09-17t192104z-486627001-rc2vtganub34-rtrmadp-3-usa-fed.JPG?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-10-29T13:30:53Z',
#    'content': 'The biggest debate among Federal Reserve officials this week isnt over interest rates.\r\nFor the past three years, the central bank has gradually reduced the size of its massive portfolio in a careful… [+1564 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Jordan Valinsky',
#    'title': 'Collapse of Sonder, a Marriott-backed hotel chain, leaves guests stranded mid-stay | CNN Business',
#    'description': 'Patrick M. D’Aoust probably didn’t expect his anniversary trip to end early, but he definitely didn’t think he’d have just 15 minutes to vacate his room.',
#    'url': 'https://www.cnn.com/2025/11/11/business/sonder-bankruptcy-marriott-deal-ends',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/9grpjdhf.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-11T18:03:14Z',
#    'content': 'Patrick M. DAoust probably didnt expect his anniversary trip to end early, but he definitely didnt think hed have just 15 minutes to vacate his room.\r\nThe early ejection wasnt because of a fire or a … [+2810 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Hadas Gold',
#    'title': 'Elon Musk launches his version of Wikipedia, Grokipedia',
#    'description': 'Elon Musk launched Grokipedia – his version of Wikipedia – on Monday, as the richest man in the world further seeks to create an alternative information and media ecosystem molded to his views.\ufeff',
#    'url': 'https://www.cnn.com/2025/10/28/tech/elon-musk-launches-grokipedia-wikipedia',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2184585949-20250728110847600.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-10-28T19:16:15Z',
#    'content': 'Elon Musk launched Grokipedia his version of Wikipedia on Monday, as the richest man in the world further seeks to create an alternative information and media ecosystem molded to his views.\r\nThe arti… [+3135 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'David Wright',
#    'title': 'Who are the Democrats voting for the government shutdown deal? | CNN Politics',
#    'description': 'A group of Democrats and one Democratic-aligned independent have helped clinch an agreement to end the government shutdown, saying they had secured a vote on the Affordable Care Act subsidies at the center of the standoff.',
#    'url': 'https://www.cnn.com/2025/11/09/politics/democrats-voting-government-shutdown-deal',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/20251109-senate-voters-split.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-10T02:43:39Z',
#    'content': 'A group of Democrats and one Democratic-aligned independent have helped clinch an agreement to end the government shutdown, saying they had secured a vote on the Affordable Care Act subsidies at the … [+5594 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Tami Luhby, Devan Cole',
#    'title': 'Millions of Americans won’t get any SNAP benefits in November under USDA plan, analysis finds | CNN Politics',
#    'description': 'Nearly 5 million food stamp recipients will not receive any benefits in November under the plan the Trump administration issued Tuesday to comply with a court order, according to a new analysis.',
#    'url': 'https://www.cnn.com/2025/11/05/politics/november-snap-benefits-usda-plan',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/ap25300800605844.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-06T02:52:48Z',
#    'content': 'Nearly 5 million food stamp recipients will not receive any benefits in November under the plan the Trump administration issued Tuesday to comply with a court order, according to a new analysis.\r\nTha… [+6163 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Adam Cancryn, Tami Luhby',
#    'title': 'Trump expected to unveil new health care cost proposal | CNN Politics',
#    'description': 'President Donald Trump is planning to unveil a new proposal for addressing health care costs as soon as Monday, as his administration tries to avert a spike in premiums driven by the expiration of key Affordable Care Act subsidies, three people familiar with …',
#    'url': 'https://www.cnn.com/2025/11/23/politics/trump-health-care-proposal',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2247391327-20251124022545116.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-24T04:56:02Z',
#    'content': 'President Donald Trump is planning to unveil a new proposal for addressing health care costs as soon as Monday, as his administration tries to avert a spike in premiums driven by the expiration of ke… [+5278 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': 'National 211 hotline calls for food assistance quadrupled in a matter of days, a magnitude typically seen during disasters',
#    'description': 'Between January and mid-October 2025, calls to local 211 helplines from people seeking food pantries in their community held steady at nearly 1,000 calls per day.',
#    'url': 'https://www.cnn.com/2025/11/08/health/211-food-assistance-hotline-snap',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/ap25310641973312.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-08T12:14:23Z',
#    'content': 'EDITORS NOTE:\xa0 The views expressed in this commentary are solely those of the writer. CNN is showcasing the work of The Conversation, a collaboration between journalists and academics to provide news… [+7524 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Brenda Goodman',
#    'title': 'A new virus variant and lagging vaccinations may mean the US is in for a severe flu season | CNN',
#    'description': 'The United States may be heading into its second severe flu season in a row, driven by a mutated strain called subclade K that’s behind early surges in the United Kingdom, Canada and Japan.',
#    'url': 'https://www.cnn.com/2025/11/18/health/new-flu-variant-subclade-k',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/ap25259066291775.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-18T13:14:33Z',
#    'content': 'The United States may be heading into its second severe flu season in a row, driven by a mutated strain called subclade K thats behind early surges in the United Kingdom, Canada and Japan.\r\nLast wint… [+7112 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Kylie Atwood',
#    'title': 'Last nuclear treaty between US and Russia nears expiration as Trump and Putin trade testing threats | CNN Politics',
#    'description': 'US President Donald Trump and Russian President Vladimir Putin have spent weeks trading threats to restart nuclear tests, an escalation kicked off by Putin’s boasts about tests of the Poseidon nuclear powered missile in late October.',
#    'url': 'https://www.cnn.com/2025/11/16/politics/us-russia-nuclear-treaty',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2230342714.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-16T10:47:04Z',
#    'content': 'US President Donald Trump and Russian President Vladimir Putin have spent weeks trading threats to restart nuclear tests, an escalation kicked off by Putins boasts about tests of the Poseidon nuclear… [+8465 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Sarah Ferris, Dana Bash',
#    'title': 'Nancy Pelosi announces she will not seek reelection to Congress after nearly 40 years in Washington | CNN Politics',
#    'description': 'Nancy Pelosi, the first and only female speaker of the US House of Representatives and one of the most powerful figures in Democratic politics for decades, has announced she will not seek reelection.',
#    'url': 'https://www.cnn.com/2025/11/06/politics/nancy-pelosi-congress-retirement',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/2024-08-22t020826z-720136315-hp1ek8m05xz5l-rtrmadp-3-usa-election-democrats.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-06T14:03:26Z',
#    'content': 'Nancy Pelosi, the first and only female speaker of the US House of Representatives and one of the most powerful figures in Democratic politics for decades, has announced she will not seek reelection.… [+8174 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Daniel Dale',
#    'title': 'Fact check: Trump’s lying spree about inflation | CNN Politics',
#    'description': 'President Donald Trump went on a lying spree about inflation last week.',
#    'url': 'https://www.cnn.com/2025/11/10/politics/inflation-trump-fact-check',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2244638336.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-10T19:45:00Z',
#    'content': 'President Donald Trump went on a lying spree about inflation last week.\r\nGrocery prices. Gas prices. Prescription drug prices. Overall prices. Over just three days, Trump made false claims about all … [+7854 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': 'The trend of unproven peptides is spreading through influencers and RFK Jr. allies | CNN',
#    'description': 'More Americans are injecting themselves with unapproved chemicals that are pitched as ways to build muscle, rejuvenate skin and extend life, the latest example of the nation’s fascination with alternative therapies and wellness hacks.',
#    'url': 'https://www.cnn.com/2025/11/15/health/peptides-unregulated-influencers',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/ap25294501695351.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-15T14:34:01Z',
#    'content': 'More Americans are injecting themselves with unapproved chemicals that are pitched as ways to build muscle, rejuvenate skin and extend life, the latest example of the nations fascination with alterna… [+8352 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Tami Luhby, Gabe Cohen',
#    'title': 'ACA enrollment: Skyrocketing health insurance premiums force enrollees to make tough decisions',
#    'description': 'Millions of Americans with Affordable Care Act policies are contending with the looming lapse of the enhanced subsidies. The increased cost of coverage can lead to agonizing tradeoffs for many enrollees.',
#    'url': 'https://www.cnn.com/2025/11/09/politics/aca-enrollment-premiums-increase-impact',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2244046654.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-09T10:07:26Z',
#    'content': 'Late last month, Elizabeth Wick got the email she had been dreading. Her insurer, Blue Cross and Blue Shield of Texas, told her that the monthly premiums for her Affordable Care Act policy would soar… [+9626 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': 'Disease of 1,000 faces shows how science is tackling immunity’s dark side | CNN',
#    'description': 'Doctor after doctor misdiagnosed or shrugged off Ruth Wilson’s rashes, swelling, fevers and severe pain for six years. She saved her life by begging for one more test in an emergency room about to send her home, again, without answers.',
#    'url': 'https://www.cnn.com/2025/11/07/health/autoimmune-disease-science',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/01-ap25310061469429.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-07T14:49:36Z',
#    'content': 'Doctor after doctor misdiagnosed or shrugged off Ruth Wilsons rashes, swelling, fevers and severe pain for six years. She saved her life by begging for one more test in an emergency room about to sen… [+10890 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': 'US funding cuts imperil global efforts to eliminate cervical cancer | CNN',
#    'description': 'Maina Modu, an immunization officer in Nigeria’s northeastern Borno state, lost his wife, Hauwa, to cervical cancer in 2011. She was one of the 349,000 women globally who die from the preventable cancer every year. Thirteen years later, he jumped at the chanc…',
#    'url': 'https://www.cnn.com/2025/11/17/health/cervical-cancer-hpv-vaccine-gavi-funding',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/20240528-071730.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-11-18T05:14:23Z',
#    'content': 'EDITORS NOTE:\xa0 This story was reported in collaboration with the Global Health Reporting Center with support from the Pulitzer Center.\r\nMaina Modu, an immunization officer in Nigerias northeastern Bo… [+15944 chars]'}]}

# %%
json_data['articles']
#json_data['status']
# Out:
# [{'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Deidre McPhillips, CNN',
#   'title': 'Canada is poised to lose its measles elimination status — and the US could, too',
#   'description': 'Monday marks a full year of continuous measles transmission in Canada, a milestone that’s poised to set the country back decades on a global health...',
#   'url': 'https://www.cnn.com/2025/10/27/health/measles-elimination-canada-us-who',
#   'urlToImage': 'https://media.zenfs.com/en/cnn_articles_875/a33f02fd4b2d2da1f28596d69fa6b7d1',
#   'publishedAt': '2025-10-27T11:00:01Z',
#   'content': 'Monday marks a full year of continuous measles transmission in Canada, a milestone thats poised to set the country back decades on a global health commitment. Ongoing transmission in the United State… [+8753 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Issy Ronald, CNN',
#   'title': 'Qantas releases first images of jet that will fly nonstop from Sydney to London and New York',
#   'description': 'Australia’s flag carrier will use Airbus A350-1000ULR jets for its “Project Sunrise” service which will fly nonstop from Sydney to London and New York.',
#   'url': 'https://www.cnn.com/2025/11/07/travel/qantas-airbus-project-sunrise-plane-nonstop-intl-scli',
#   'urlToImage': 'https://media.zenfs.com/en/cnn_articles_875/0ae7372671db0681955525fd3410e0b6',
#   'publishedAt': '2025-11-07T14:50:24Z',
#   'content': 'Just 80 years ago, traveling to Sydney or Melbourne from London or New York took more than a week.\r\nNow, a passenger aircraft that can complete make the journey without stopping is in the final stage… [+2434 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Deidre McPhillips',
#   'title': 'Autism diagnosis rates higher among children born to mothers who had Covid-19 during pregnancy, study suggests | CNN',
#   'description': 'Children may be more likely to be diagnosed with autism and other neurodevelopment disorders if their mother had a Covid-19 infection while pregnant, according to a new study.',
#   'url': 'https://www.cnn.com/2025/10/30/health/autism-covid-pregnancy',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-1322499124.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-10-31T00:29:08Z',
#   'content': 'Children may be more likely to be diagnosed with autism and other neurodevelopment disorders if their mother had a Covid-19 infection while pregnant, according to a new study.\r\nResearchers from Massa… [+3906 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Bryan Mena, Elisabeth Buchwald, John Towfighi, Matt Egan',
#   'title': 'Live updates: Fed looks set to cut rates for second time this year despite data blackout due to government shutdown',
#   'description': 'The Federal Reserve was widely expected to lower interest rates by a quarter point in order to support the waning job market.',
#   'url': 'https://www.cnn.com/business/live-news/federal-reserve-interest-rate-10-29-25',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/2025-09-17t192104z-486627001-rc2vtganub34-rtrmadp-3-usa-fed.JPG?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-10-29T13:30:53Z',
#   'content': 'The biggest debate among Federal Reserve officials this week isnt over interest rates.\r\nFor the past three years, the central bank has gradually reduced the size of its massive portfolio in a careful… [+1564 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Jordan Valinsky',
#   'title': 'Collapse of Sonder, a Marriott-backed hotel chain, leaves guests stranded mid-stay | CNN Business',
#   'description': 'Patrick M. D’Aoust probably didn’t expect his anniversary trip to end early, but he definitely didn’t think he’d have just 15 minutes to vacate his room.',
#   'url': 'https://www.cnn.com/2025/11/11/business/sonder-bankruptcy-marriott-deal-ends',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/9grpjdhf.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-11T18:03:14Z',
#   'content': 'Patrick M. DAoust probably didnt expect his anniversary trip to end early, but he definitely didnt think hed have just 15 minutes to vacate his room.\r\nThe early ejection wasnt because of a fire or a … [+2810 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Hadas Gold',
#   'title': 'Elon Musk launches his version of Wikipedia, Grokipedia',
#   'description': 'Elon Musk launched Grokipedia – his version of Wikipedia – on Monday, as the richest man in the world further seeks to create an alternative information and media ecosystem molded to his views.\ufeff',
#   'url': 'https://www.cnn.com/2025/10/28/tech/elon-musk-launches-grokipedia-wikipedia',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2184585949-20250728110847600.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-10-28T19:16:15Z',
#   'content': 'Elon Musk launched Grokipedia his version of Wikipedia on Monday, as the richest man in the world further seeks to create an alternative information and media ecosystem molded to his views.\r\nThe arti… [+3135 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'David Wright',
#   'title': 'Who are the Democrats voting for the government shutdown deal? | CNN Politics',
#   'description': 'A group of Democrats and one Democratic-aligned independent have helped clinch an agreement to end the government shutdown, saying they had secured a vote on the Affordable Care Act subsidies at the center of the standoff.',
#   'url': 'https://www.cnn.com/2025/11/09/politics/democrats-voting-government-shutdown-deal',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/20251109-senate-voters-split.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-10T02:43:39Z',
#   'content': 'A group of Democrats and one Democratic-aligned independent have helped clinch an agreement to end the government shutdown, saying they had secured a vote on the Affordable Care Act subsidies at the … [+5594 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Tami Luhby, Devan Cole',
#   'title': 'Millions of Americans won’t get any SNAP benefits in November under USDA plan, analysis finds | CNN Politics',
#   'description': 'Nearly 5 million food stamp recipients will not receive any benefits in November under the plan the Trump administration issued Tuesday to comply with a court order, according to a new analysis.',
#   'url': 'https://www.cnn.com/2025/11/05/politics/november-snap-benefits-usda-plan',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/ap25300800605844.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-06T02:52:48Z',
#   'content': 'Nearly 5 million food stamp recipients will not receive any benefits in November under the plan the Trump administration issued Tuesday to comply with a court order, according to a new analysis.\r\nTha… [+6163 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Adam Cancryn, Tami Luhby',
#   'title': 'Trump expected to unveil new health care cost proposal | CNN Politics',
#   'description': 'President Donald Trump is planning to unveil a new proposal for addressing health care costs as soon as Monday, as his administration tries to avert a spike in premiums driven by the expiration of key Affordable Care Act subsidies, three people familiar with …',
#   'url': 'https://www.cnn.com/2025/11/23/politics/trump-health-care-proposal',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2247391327-20251124022545116.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-24T04:56:02Z',
#   'content': 'President Donald Trump is planning to unveil a new proposal for addressing health care costs as soon as Monday, as his administration tries to avert a spike in premiums driven by the expiration of ke… [+5278 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': None,
#   'title': 'National 211 hotline calls for food assistance quadrupled in a matter of days, a magnitude typically seen during disasters',
#   'description': 'Between January and mid-October 2025, calls to local 211 helplines from people seeking food pantries in their community held steady at nearly 1,000 calls per day.',
#   'url': 'https://www.cnn.com/2025/11/08/health/211-food-assistance-hotline-snap',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/ap25310641973312.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-08T12:14:23Z',
#   'content': 'EDITORS NOTE:\xa0 The views expressed in this commentary are solely those of the writer. CNN is showcasing the work of The Conversation, a collaboration between journalists and academics to provide news… [+7524 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Brenda Goodman',
#   'title': 'A new virus variant and lagging vaccinations may mean the US is in for a severe flu season | CNN',
#   'description': 'The United States may be heading into its second severe flu season in a row, driven by a mutated strain called subclade K that’s behind early surges in the United Kingdom, Canada and Japan.',
#   'url': 'https://www.cnn.com/2025/11/18/health/new-flu-variant-subclade-k',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/ap25259066291775.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-18T13:14:33Z',
#   'content': 'The United States may be heading into its second severe flu season in a row, driven by a mutated strain called subclade K thats behind early surges in the United Kingdom, Canada and Japan.\r\nLast wint… [+7112 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Kylie Atwood',
#   'title': 'Last nuclear treaty between US and Russia nears expiration as Trump and Putin trade testing threats | CNN Politics',
#   'description': 'US President Donald Trump and Russian President Vladimir Putin have spent weeks trading threats to restart nuclear tests, an escalation kicked off by Putin’s boasts about tests of the Poseidon nuclear powered missile in late October.',
#   'url': 'https://www.cnn.com/2025/11/16/politics/us-russia-nuclear-treaty',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2230342714.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-16T10:47:04Z',
#   'content': 'US President Donald Trump and Russian President Vladimir Putin have spent weeks trading threats to restart nuclear tests, an escalation kicked off by Putins boasts about tests of the Poseidon nuclear… [+8465 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Sarah Ferris, Dana Bash',
#   'title': 'Nancy Pelosi announces she will not seek reelection to Congress after nearly 40 years in Washington | CNN Politics',
#   'description': 'Nancy Pelosi, the first and only female speaker of the US House of Representatives and one of the most powerful figures in Democratic politics for decades, has announced she will not seek reelection.',
#   'url': 'https://www.cnn.com/2025/11/06/politics/nancy-pelosi-congress-retirement',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/2024-08-22t020826z-720136315-hp1ek8m05xz5l-rtrmadp-3-usa-election-democrats.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-06T14:03:26Z',
#   'content': 'Nancy Pelosi, the first and only female speaker of the US House of Representatives and one of the most powerful figures in Democratic politics for decades, has announced she will not seek reelection.… [+8174 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Daniel Dale',
#   'title': 'Fact check: Trump’s lying spree about inflation | CNN Politics',
#   'description': 'President Donald Trump went on a lying spree about inflation last week.',
#   'url': 'https://www.cnn.com/2025/11/10/politics/inflation-trump-fact-check',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2244638336.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-10T19:45:00Z',
#   'content': 'President Donald Trump went on a lying spree about inflation last week.\r\nGrocery prices. Gas prices. Prescription drug prices. Overall prices. Over just three days, Trump made false claims about all … [+7854 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': None,
#   'title': 'The trend of unproven peptides is spreading through influencers and RFK Jr. allies | CNN',
#   'description': 'More Americans are injecting themselves with unapproved chemicals that are pitched as ways to build muscle, rejuvenate skin and extend life, the latest example of the nation’s fascination with alternative therapies and wellness hacks.',
#   'url': 'https://www.cnn.com/2025/11/15/health/peptides-unregulated-influencers',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/ap25294501695351.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-15T14:34:01Z',
#   'content': 'More Americans are injecting themselves with unapproved chemicals that are pitched as ways to build muscle, rejuvenate skin and extend life, the latest example of the nations fascination with alterna… [+8352 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Tami Luhby, Gabe Cohen',
#   'title': 'ACA enrollment: Skyrocketing health insurance premiums force enrollees to make tough decisions',
#   'description': 'Millions of Americans with Affordable Care Act policies are contending with the looming lapse of the enhanced subsidies. The increased cost of coverage can lead to agonizing tradeoffs for many enrollees.',
#   'url': 'https://www.cnn.com/2025/11/09/politics/aca-enrollment-premiums-increase-impact',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2244046654.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-09T10:07:26Z',
#   'content': 'Late last month, Elizabeth Wick got the email she had been dreading. Her insurer, Blue Cross and Blue Shield of Texas, told her that the monthly premiums for her Affordable Care Act policy would soar… [+9626 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': None,
#   'title': 'Disease of 1,000 faces shows how science is tackling immunity’s dark side | CNN',
#   'description': 'Doctor after doctor misdiagnosed or shrugged off Ruth Wilson’s rashes, swelling, fevers and severe pain for six years. She saved her life by begging for one more test in an emergency room about to send her home, again, without answers.',
#   'url': 'https://www.cnn.com/2025/11/07/health/autoimmune-disease-science',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/01-ap25310061469429.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-07T14:49:36Z',
#   'content': 'Doctor after doctor misdiagnosed or shrugged off Ruth Wilsons rashes, swelling, fevers and severe pain for six years. She saved her life by begging for one more test in an emergency room about to sen… [+10890 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': None,
#   'title': 'US funding cuts imperil global efforts to eliminate cervical cancer | CNN',
#   'description': 'Maina Modu, an immunization officer in Nigeria’s northeastern Borno state, lost his wife, Hauwa, to cervical cancer in 2011. She was one of the 349,000 women globally who die from the preventable cancer every year. Thirteen years later, he jumped at the chanc…',
#   'url': 'https://www.cnn.com/2025/11/17/health/cervical-cancer-hpv-vaccine-gavi-funding',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/20240528-071730.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2025-11-18T05:14:23Z',
#   'content': 'EDITORS NOTE:\xa0 This story was reported in collaboration with the Global Health Reporting Center with support from the Pulitzer Center.\r\nMaina Modu, an immunization officer in Nigerias northeastern Bo… [+15944 chars]'}]

# %% [markdown]
# The return value `json_data` is just a dictionary collecting information about the remote request

# %%
print(type(json_data))
print()
print(json_data.keys())
print()
print('The status of the request is',json_data['status'],'There are ',json_data['totalResults'],'articles matching the request.')
print('We got',len(json_data['articles']),'articles')
print()
# Out:
# <class 'dict'>
#
# dict_keys(['status', 'totalResults', 'articles'])
#
# The status of the request is ok There are  18 articles matching the request.
# We got 18 articles

# %%
articles = json_data['articles']

print(type(articles))
print(type(articles[0]))
print(articles[0].keys())
# Out:
# <class 'list'>
# <class 'dict'>
# dict_keys(['source', 'author', 'title', 'description', 'url', 'urlToImage', 'publishedAt', 'content'])

# %%
first_article=articles[0]
first_article
# Out:
# {'source': {'id': 'cnn', 'name': 'CNN'},
#  'author': 'Deidre McPhillips, CNN',
#  'title': 'Canada is poised to lose its measles elimination status — and the US could, too',
#  'description': 'Monday marks a full year of continuous measles transmission in Canada, a milestone that’s poised to set the country back decades on a global health...',
#  'url': 'https://www.cnn.com/2025/10/27/health/measles-elimination-canada-us-who',
#  'urlToImage': 'https://media.zenfs.com/en/cnn_articles_875/a33f02fd4b2d2da1f28596d69fa6b7d1',
#  'publishedAt': '2025-10-27T11:00:01Z',
#  'content': 'Monday marks a full year of continuous measles transmission in Canada, a milestone thats poised to set the country back decades on a global health commitment. Ongoing transmission in the United State… [+8753 chars]'}

# %% [markdown]
# We can ignore all the metadata (i.e. the data about the remote request) and focus on the actual articles only

# %%
#Get the description of the first article
content = articles[0]['description']
print('The content is long',len(content),"characters")
print()
print('The content:')
print(content)
# Out:
# The content is long 150 characters
#
# The content:
# Monday marks a full year of continuous measles transmission in Canada, a milestone that’s poised to set the country back decades on a global health...

# %% [markdown]
# Now let's combine the content of all the news into variable `contents`

# %%
def combine_articles(list_of_articles):
    contents = ''
    for article in list_of_articles:
         #  check if key 'description' has Non-None value in dictionary 
        if article['description']:
            contents += article['description']+" "
            
    return contents

contents = combine_articles(articles)
print('Overall we have',len(contents),'characters')
contents
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 10
#       6             contents += article['description']+" "
#       8     return contents
# ---> 10 contents = combine_articles(articles)
#      11 print('Overall we have',len(contents),'characters')
#      12 contents
#
# NameError: name 'articles' is not defined

# %% [markdown]
# # Data cleaning, manipulation and visualization

# %% [markdown]
# ## Implementing two functions for data cleaning

# %% [markdown]
# __Stop words__ are usually the most common words in any text ( like “the”, “of”, “to” and “and”),
# * They don’t tell us much about the actual content in a text
# * These are the words we want to ignore - this is our data cleaning
#
# We want to find the words that will help us differentiate a text from texts that are about different subjects.
# * __We will filter out the common words__.
# * Of course, we are going to use a function for doing this

# %% [markdown]
# Furthermore, we want to ignore punctuation
# * In Python, string.punctuation will give the all sets of punctuation.
# * We are going to use it to delete all punctuation from a string

# %%
STOPWORDS
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# to remove STOPWORDS from a list of strings
def remove_stopwords(wordlist):
    return [ w for w in wordlist if w not in STOPWORDS ]

# to remove Punctuations from a string
def remove_punctuations(my_str): 
    no_punct = ""
    for char in my_str:
        if char  not in string.punctuation:
            no_punct = no_punct + char
    return no_punct

# %%
# for testing 
remove_punctuations('Andrea likes pizza and Python!! and,,,,, you? . ' + "ciao")
# Out:
# 'Andrea likes pizza and Python and you  ciao'

# %%
no_punct=remove_punctuations('Andrea likes pizza and Python!! and you? . ' + "ciao")
print(no_punct)
no_punct.split()
# Out:
# Andrea likes pizza and Python and you  ciao
# ['Andrea', 'likes', 'pizza', 'and', 'Python', 'and', 'you', 'ciao']

# %%
clean_str=remove_punctuations('Andrea likes pizza and Python!! and you? . ' + "ciao")
print(clean_str)

clean_str.split()
# Out:
# Andrea likes pizza and Python and you  ciao
# ['Andrea', 'likes', 'pizza', 'and', 'Python', 'and', 'you', 'ciao']

# %%
remove_stopwords(
    remove_punctuations('Andrea likes pizza and Python!! and you? . ' + "ciao").split()
    )
# Out:
# ['Andrea', 'likes', 'pizza', 'Python', 'ciao']

# %% [markdown]
# ## Actual cleaning, manipulation, visualization

# %% [markdown]
# Now begins the funny part
# 1. Let's clean the data removing not interesting words
# 2. Let's compute the frequency of use of words
# 3. Let's visualize graphically the computed analysis - Word Cloud

# %%
#contents

# %%
# 1 cleaning data
def clean_data(content_to_clean):
    print('Before cleaning')
    print(content_to_clean[:200])
    print()
    # simple text normalization: string in lower case
    content_to_clean = content_to_clean.lower()
    # remove punctuations
    cleaned_content = remove_punctuations(content_to_clean)
    # remove stopwords
    #   split the string in a list of words
    cleaned_content_words = cleaned_content.split()
    #   remove stop_words
    cleaned_content_words = remove_stopwords(cleaned_content_words)
    print('After cleaning')
    print(cleaned_content_words[:200])
    print()
    return cleaned_content_words

cleaned_content = clean_data(contents)
#cleaned_content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 20
#      17     print()
#      18     return cleaned_content_words
# ---> 20 cleaned_content = clean_data(contents)
#      21 #cleaned_content
#
# NameError: name 'contents' is not defined

# %%
# 2 computing word-frequency pairs
def analyze_data(cleaned_content):
    wordcount = {}
    for w in cleaned_content:
        if w in wordcount:
            #wordcount[w] += 1
            wordcount[w] = wordcount[w] + 1
        else:
            wordcount[w] = 1
    return wordcount

#wordcount = analyze_data(['ciao','ciao','andrea'])
wordcount = analyze_data(cleaned_content)
wordcount
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 13
#      10     return wordcount
#      12 #wordcount = analyze_data(['ciao','ciao','andrea'])
# ---> 13 wordcount = analyze_data(cleaned_content)
#      14 wordcount
#
# NameError: name 'cleaned_content' is not defined

# %%
# 3 visualizing the analysisis in a Word Cloud
def visualize_data(wordcount,width=1200,height=600,background_color='white'):
    wordCloudMaker=WordCloud(width=width,height=height, background_color=background_color)
    wc = wordCloudMaker.generate_from_frequencies(wordcount)
    plt.figure(figsize=(20,10))
    plt.imshow(wc)
    plt.axis("off")
    plt.show()

visualize_data(wordcount)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 10
#       7     plt.axis("off")
#       8     plt.show()
# ---> 10 visualize_data(wordcount)
#
# NameError: name 'wordcount' is not defined

# %% [markdown]
# # Let's put everything in a function, so that we can run it easily for different sources

# %% [raw]
# my_api_key='1f6979fc955b465f9b076310217a19a3'
# #newsapi = NewsApiClient(api_key='345f8a0aa8c64d549fde1d8343d036f8')
# newsapi = NewsApiClient(api_key=my_api_key)
# json_data = newsapi.get_everything(
#                                     #q='coronavirus',        # All the articles that contain this word
#                                     q='hamas',              # All the articles that contain this word
#                                     language='en',
#                                     #sources = 'usa-today', # The newspaper of interest
#                                     sources = 'cnn', # The newspaper of interest
#                                     #sources = 'bbc-news', # The newspaper of interest
#                                     #sources = 'bbc-news,the-verge'
#                                     #
#                                     page_size=100,           # Get 100 articles
#                                     sort_by='relevancy'
#                                     )
# #There exist many more parameters allowing us the ask for more articles, different sources, etc
#
# #print(json_data)

# %%
def make_world_cloud(query,source,n_articles=50):
    """
    Download relevant 'n_article' articles that contain 'query' from 'source' newspaper using NewsAPI
    and plot a wordcloud with the most common words in the corpus.
    :param query: 
        Keywords or phrases to search for in the article title and body.
    :param source: 
        the news source or blog you want headlines from
    :param n_articles:
        The number of articles to return (maximum 100)
    """
    # 1.  Download all the articles the online service NewsAPI
    newsapi = NewsApiClient(api_key=my_api_key)
    json_data = newsapi.get_everything(q=query,           # All the articles that contain this word
                                       language='en',
                                       sources=source,      # The newspaper of interest
                                       page_size=n_articles,  # Get 50 articles (by default)
                                       sort_by='relevancy'
                                    )
    
    # 2. Combine the articles into one document (string)
    contents = combine_articles(json_data['articles'])
    
    # 3. cleaning data
    cleaned_content = clean_data(contents)

    # 4. computing word-frequency pairs
    wordcount = analyze_data(cleaned_content)
 
    # 5. Visualizing the analysis in a Word Cloud
    visualize_data(wordcount)

# %%
help(make_world_cloud)
# Out:
# Help on function make_world_cloud in module __main__:
#
# make_world_cloud(query, source, n_articles=50)
#     Download relevant 'n_article' articles that contain 'query' from 'source' newspaper using NewsAPI
#     and plot a wordcloud with the most common words in the corpus.
#     :param query:
#         Keywords or phrases to search for in the article title and body.
#     :param source:
#         the news source or blog you want headlines from
#     :param n_articles:
#         The number of articles to return (maximum 100)

# %%
#make_world_cloud('coronavirus','the-verge',100)
make_world_cloud('hamas','cnn',100)
# Out:
# Before cleaning
# British commentator Sami Hamdi was detained on Sunday by federal immigration officers during a speaking tour in the United States, in what a Muslim advocacy ... Radiohead singer Thom Yorke has said he
#
# After cleaning
# ['british', 'commentator', 'sami', 'hamdi', 'detained', 'sunday', 'federal', 'immigration', 'officers', 'speaking', 'tour', 'united', 'states', 'muslim', 'advocacy', 'radiohead', 'singer', 'thom', 'yorke', 'said', 'longer', 'perform', 'israel', 'band', 'came', 'scrutiny', 'playing', 'tel', 'aviv', '2017', 'israeli', 'authorities', 'said', 'monday', 'received', 'coffin', 'deceased', 'hostage', 'gaza', 'austria’s', 'domestic', 'intelligence', 'service', 'uncovered', 'weapons', 'cache', 'vienna', 'believed', 'linked', 'palestinian', 'militant', 'group', 'hamas', 'use', '“possible', 'terrorist', 'attacks', 'europe”', 'government', 'said', 'thursday', 'prime', 'minister', 'benjamin', 'netanyahu', 'tuesday', 'ordered', 'israeli', 'military', 'carry', '“immediate', 'powerful”', 'strikes', 'gaza', 'recently', 'freed', 'israeli', 'hostage', 'alleged', 'subjected', '“horrific”', 'humiliating', 'sexual', 'assault', 'held', 'captive', 'gaza', 'turkey', 'friday', 'issued', 'arrest', 'warrants', 'israeli', 'prime', 'minister', 'benjamin', 'netanyahu', 'dozens', 'israeli', 'officials', '“genocide”', 'charges', 'israeli', 'strike', 'palestinian', 'refugee', 'camp', 'southern', 'lebanon', 'killed', '13', 'people', 'tuesday', 'according', 'lebanese', 'health', 'ministry', 'president', 'donald', 'trump', 'planning', 'receive', 'saudi', 'arabia’s', 'powerful', 'crown', 'prince', 'mohammed', 'bin', 'salman', 'white', 'house', 'week', 'trappings', 'state', 'visit', 'sources', 'familiar', 'matter', 'said', 'including', 'welcome', 'ceremony', 'morning', 'and…', 'president', 'donald', 'trump', 'littered', 'new', '“60', 'minutes”', 'interview', 'wideranging', 'assortment', 'false', 'claims', 'vast', 'majority', 'previously', 'debunked', 'counted', 'least', '18', 'inaccurate', 'assertions']

# %%
make_world_cloud('hamas','bbc-news',100)
# Out:
# Before cleaning
# Hurricane Melissa has made landfall in Jamaica - its most powerful storm since records began. The US National Hurricane Centre said the eye hit the southwest of the island with estimated maximum wind
#
# After cleaning
# ['hurricane', 'melissa', 'made', 'landfall', 'jamaica', 'powerful', 'storm', 'records', 'began', 'us', 'national', 'hurricane', 'centre', 'said', 'eye', 'hit', 'southwest', 'island', 'estimated', 'maximum', 'wind', 'speeds', 'close', 'three', 'hundred', 'kilometres', 'hour', 'in…', 'entire', 'neighbourhoods', 'controlled', 'israel', 'levelled', 'less', 'month', 'images', 'show', 'maj', 'gen', 'yifat', 'tomeryerushalmi', 'resigned', 'friday', 'admitting', 'leaking', 'video', 'allegedly', 'showing', 'abuse', 'palestinian', 'detainee']

# %%
make_world_cloud("italy",'usa-today',100)
# Out:
# Before cleaning
# Sixteen European teams will battle for four spots in the 2026 World Cup. See the pairings for the matches next March. Europe will have 16 representative sin the 2026 World Cup and four are still up fo
#
# After cleaning
# ['sixteen', 'european', 'teams', 'will', 'battle', 'four', 'spots', '2026', 'world', 'cup', 'see', 'pairings', 'matches', 'next', 'march', 'europe', 'will', '16', 'representative', 'sin', '2026', 'world', 'cup', 'four', 'still', 'grabs', '42', 'teams', 'qualified', 'three', 'countries', 'set', 'make', 'debut', 'big', 'stage', 'first', 'time', 'five', 'weeks', 'commanders', 'held', 'lead', 'one', 'several', 'factsnumbers', 'week', '11', '2026', 'world', 'cups', '48', 'spots', '30', 'already', 'claimed', 'secured', 'qualifiers', 'take', 'place', 'november', 'blanca', 'quiñonez', 'named', 'big', 'east', 'freshman', 'week', 'averaging', '115', 'points', '25', 'rebounds', '2', 'assists', '15', 'steals', 'first', 'two', 'games', 'walters', 'golf’s', 'version', 'mick', 'jagger', 'bruce', 'springsteen', 'still', 'rocking', 'age', '76', 'performing', 'shows', 'nationwide']

# %%
make_world_cloud('hamas','cnn,bbc-news',100)
# Out:
# Before cleaning
# British commentator Sami Hamdi was detained on Sunday by federal immigration officers during a speaking tour in the United States, in what a Muslim advocacy ... Radiohead singer Thom Yorke has said he
#
# After cleaning
# ['british', 'commentator', 'sami', 'hamdi', 'detained', 'sunday', 'federal', 'immigration', 'officers', 'speaking', 'tour', 'united', 'states', 'muslim', 'advocacy', 'radiohead', 'singer', 'thom', 'yorke', 'said', 'longer', 'perform', 'israel', 'band', 'came', 'scrutiny', 'playing', 'tel', 'aviv', '2017', 'hurricane', 'melissa', 'made', 'landfall', 'jamaica', 'powerful', 'storm', 'records', 'began', 'us', 'national', 'hurricane', 'centre', 'said', 'eye', 'hit', 'southwest', 'island', 'estimated', 'maximum', 'wind', 'speeds', 'close', 'three', 'hundred', 'kilometres', 'hour', 'in…', 'israeli', 'authorities', 'said', 'monday', 'received', 'coffin', 'deceased', 'hostage', 'gaza', 'austria’s', 'domestic', 'intelligence', 'service', 'uncovered', 'weapons', 'cache', 'vienna', 'believed', 'linked', 'palestinian', 'militant', 'group', 'hamas', 'use', '“possible', 'terrorist', 'attacks', 'europe”', 'government', 'said', 'thursday', 'prime', 'minister', 'benjamin', 'netanyahu', 'tuesday', 'ordered', 'israeli', 'military', 'carry', '“immediate', 'powerful”', 'strikes', 'gaza', 'recently', 'freed', 'israeli', 'hostage', 'alleged', 'subjected', '“horrific”', 'humiliating', 'sexual', 'assault', 'held', 'captive', 'gaza', 'entire', 'neighbourhoods', 'controlled', 'israel', 'levelled', 'less', 'month', 'images', 'show', 'turkey', 'friday', 'issued', 'arrest', 'warrants', 'israeli', 'prime', 'minister', 'benjamin', 'netanyahu', 'dozens', 'israeli', 'officials', '“genocide”', 'charges', 'israeli', 'strike', 'palestinian', 'refugee', 'camp', 'southern', 'lebanon', 'killed', '13', 'people', 'tuesday', 'according', 'lebanese', 'health', 'ministry', 'maj', 'gen', 'yifat', 'tomeryerushalmi', 'resigned', 'friday', 'admitting', 'leaking', 'video', 'allegedly', 'showing', 'abuse', 'palestinian', 'detainee', 'president', 'donald', 'trump', 'planning', 'receive', 'saudi', 'arabia’s', 'powerful', 'crown', 'prince', 'mohammed', 'bin', 'salman', 'white', 'house', 'week', 'trappings', 'state', 'visit', 'sources', 'familiar', 'matter', 'said', 'including', 'welcome', 'ceremony', 'morning', 'and…', 'president', 'donald', 'trump', 'littered']

# %%
#make_world_cloud('hamas','ars-technica',100)
#make_world_cloud('geopolitics','bbc-news',100)
make_world_cloud('hamas','bbc-news',100)
#make_world_cloud('covid','cnn',100)
# Out:
# Before cleaning
# Hurricane Melissa has made landfall in Jamaica - its most powerful storm since records began. The US National Hurricane Centre said the eye hit the southwest of the island with estimated maximum wind
#
# After cleaning
# ['hurricane', 'melissa', 'made', 'landfall', 'jamaica', 'powerful', 'storm', 'records', 'began', 'us', 'national', 'hurricane', 'centre', 'said', 'eye', 'hit', 'southwest', 'island', 'estimated', 'maximum', 'wind', 'speeds', 'close', 'three', 'hundred', 'kilometres', 'hour', 'in…', 'entire', 'neighbourhoods', 'controlled', 'israel', 'levelled', 'less', 'month', 'images', 'show', 'maj', 'gen', 'yifat', 'tomeryerushalmi', 'resigned', 'friday', 'admitting', 'leaking', 'video', 'allegedly', 'showing', 'abuse', 'palestinian', 'detainee']

# %% [markdown]
# # Example from local text

# %%
#%pip install wordcloud
# creating wordclouds into your Python application 
from wordcloud import WordCloud, STOPWORDS


def make_local_wordcloud(text,width=1200,height=600,background_color='white'):
    """
    Make a wordcloud out of the text given
    :param text: 
        The text to create a wordcloud from.
    
    """
    # 1. cleaning data
    cleaned_content = clean_data(text)

    # 4. computing word-frequency pairs
    wordcount = analyze_data(cleaned_content)
 
    # 5. Visualizing the analysis in a Word Cloud
    visualize_data(wordcount,width,height,background_color)



text="machine learning, AI, model reduction, formal methods, mathematical modeling, dynamical systems, differential equations, ordinary differential equations, chemical reaction networks, biochemical networks, systems biology, network science, complex networks, lumping, aggregation, bisimulation, equivalence relations, partition refinement, symbolic computation, algebraic methods, categorical methods, process algebra, concurrency theory, stochastic models, Markov processes, continuous-time systems, control systems, optimal control, verification, model checking, statistical model checking, abstraction, scalability, approximation, coarse-graining, state-space reduction, simulation, efficient simulation, performance evaluation, algorithmic methods, computational efficiency, tool support, ERODE, software tools, automation, compositional modeling, graph theory, graph partitions, network embedding, system equivalence, dynamical networks, rational dynamical systems, bilinear systems, biological switches, noise reduction, robustness, neural networks, continuous-time neural networks, learning dynamics, interpretability, hybrid systems, electric circuits, physical systems modeling, quantum computing, quantum circuits, quantum verification, decision diagrams, computational complexity, correctness, validation, formal analysis, interdisciplinary research, computer science, applied mathematics, systems engineering, real0world models, scalable algorithms, backward equivalence, embedding, quantum, ML, ML, ML, ML, quantum, AI, AI, AI, AI"
""


width=1050
height=600
background_color='white'
make_local_wordcloud(text,width,height,background_color)
# Out:
# Before cleaning
# machine learning, AI, model reduction, formal methods, mathematical modeling, dynamical systems, differential equations, ordinary differential equations, chemical reaction networks, biochemical networ
#
# After cleaning
# ['machine', 'learning', 'ai', 'model', 'reduction', 'formal', 'methods', 'mathematical', 'modeling', 'dynamical', 'systems', 'differential', 'equations', 'ordinary', 'differential', 'equations', 'chemical', 'reaction', 'networks', 'biochemical', 'networks', 'systems', 'biology', 'network', 'science', 'complex', 'networks', 'lumping', 'aggregation', 'bisimulation', 'equivalence', 'relations', 'partition', 'refinement', 'symbolic', 'computation', 'algebraic', 'methods', 'categorical', 'methods', 'process', 'algebra', 'concurrency', 'theory', 'stochastic', 'models', 'markov', 'processes', 'continuoustime', 'systems', 'control', 'systems', 'optimal', 'control', 'verification', 'model', 'checking', 'statistical', 'model', 'checking', 'abstraction', 'scalability', 'approximation', 'coarsegraining', 'statespace', 'reduction', 'simulation', 'efficient', 'simulation', 'performance', 'evaluation', 'algorithmic', 'methods', 'computational', 'efficiency', 'tool', 'support', 'erode', 'software', 'tools', 'automation', 'compositional', 'modeling', 'graph', 'theory', 'graph', 'partitions', 'network', 'embedding', 'system', 'equivalence', 'dynamical', 'networks', 'rational', 'dynamical', 'systems', 'bilinear', 'systems', 'biological', 'switches', 'noise', 'reduction', 'robustness', 'neural', 'networks', 'continuoustime', 'neural', 'networks', 'learning', 'dynamics', 'interpretability', 'hybrid', 'systems', 'electric', 'circuits', 'physical', 'systems', 'modeling', 'quantum', 'computing', 'quantum', 'circuits', 'quantum', 'verification', 'decision', 'diagrams', 'computational', 'complexity', 'correctness', 'validation', 'formal', 'analysis', 'interdisciplinary', 'research', 'computer', 'science', 'applied', 'mathematics', 'systems', 'engineering', 'real0world', 'models', 'scalable', 'algorithms', 'backward', 'equivalence', 'embedding', 'quantum', 'ml', 'ml', 'ml', 'ml', 'quantum', 'ai', 'ai', 'ai', 'ai']
